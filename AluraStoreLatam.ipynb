# %% [markdown]
# <a href="https://colab.research.google.com/github/taniagoa/Primer-challenge-DC/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
total= tienda['Precio'].sum()
total
# Out:
# np.float64(1150880400.0)

# %%
total2= tienda2['Precio'].sum()
total2
# Out:
# np.float64(1116343500.0)

# %%
total3= tienda3['Precio'].sum()
total3
# Out:
# np.float64(1098019600.0)

# %%
total4= tienda4['Precio'].sum()
total4
# Out:
# np.float64(1038375700.0)

# %% [markdown]
# # 2. Ventas por categoría

# %%
Prod_vendidos=tienda.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
Prod_vendidos.plot(kind='bar',figsize=(4,2),color='purple',xlabel='Categoría del producto',ylabel='productos vendidos',title='Productos mas vendidos por categoria')
precios_mas_vendidos=tienda.groupby('Categoría del Producto')['Precio'].mean().sort_values(ascending=False)
precios_mas_vendidos
# Out:
# Categoría del Producto
# Electrodomésticos          1.165658e+06
# Electrónicos               9.586908e+05
# Instrumentos musicales     5.016429e+05
# Muebles                    4.035133e+05
# Deportes y diversión       1.383451e+05
# Artículos para el hogar    7.425965e+04
# Juguetes                   5.554228e+04
# Libros                     5.077977e+04
# Name: Precio, dtype: float64

# %%
Prod_vendidos2=tienda2.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
Prod_vendidos2.plot(kind='bar',figsize=(4,2),color='green',xlabel='Categoría del producto',ylabel='productos vendidos',title='Productos mas vendidos por categoria')
precios_mas_vendidos2=tienda2.groupby('Categoría del Producto')['Precio'].mean().sort_values(ascending=False)
precios_mas_vendidos2
# Out:
# Categoría del Producto
# Electrodomésticos          1.142845e+06
# Electrónicos               9.735334e+05
# Instrumentos musicales     4.687067e+05
# Muebles                    3.991545e+05
# Deportes y diversión       1.263436e+05
# Artículos para el hogar    8.147459e+04
# Libros                     5.122437e+04
# Juguetes                   5.094377e+04
# Name: Precio, dtype: float64

# %%
Prod_vendidos3=tienda3.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
Prod_vendidos3.plot(kind='bar',figsize=(4,2),color='blue',xlabel='Categoría del producto',ylabel='productos vendidos',title='Productos mas vendidos por categoria')
precios_mas_vendidos3=tienda3.groupby('Categoría del Producto')['Precio'].mean().sort_values(ascending=False)
precios_mas_vendidos3
# Out:
# Categoría del Producto
# Electrodomésticos          1.184309e+06
# Electrónicos               9.108111e+05
# Instrumentos musicales     4.371802e+05
# Muebles                    4.029501e+05
# Deportes y diversión       1.284949e+05
# Artículos para el hogar    8.508475e+04
# Juguetes                   6.159079e+04
# Libros                     5.134432e+04
# Name: Precio, dtype: float64

# %%
Prod_vendidos4=tienda4.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
Prod_vendidos4.plot(kind='bar',figsize=(4,2),color='yellow',xlabel='Categoría del producto',ylabel='productos vendidos',title='Productos mas vendidos por categoria')
precios_mas_vendidos4=tienda4.groupby('Categoría del Producto')['Precio'].mean().sort_values(ascending=False)
precios_mas_vendidos4
# Out:
# Categoría del Producto
# Electrodomésticos          1.115198e+06
# Electrónicos               9.079293e+05
# Instrumentos musicales     4.417788e+05
# Muebles                    4.011019e+05
# Deportes y diversión       1.203975e+05
# Artículos para el hogar    7.499751e+04
# Juguetes                   5.994734e+04
# Libros                     4.984652e+04
# Name: Precio, dtype: float64

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
Calif_Prom=round(tienda['Calificación'].mean(),2)
Calif_Prom
# Out:
# np.float64(3.98)

# %%
Calif_Prom2=round(tienda2['Calificación'].mean(),2)
Calif_Prom2
# Out:
# np.float64(4.04)

# %%
Calif_Prom3=round(tienda3['Calificación'].mean(),2)
Calif_Prom3
# Out:
# np.float64(4.05)

# %%
Calif_Prom4=round(tienda4['Calificación'].mean(),2)
Calif_Prom4
# Out:
# np.float64(4.0)

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
mas_vendido=tienda['Producto'].value_counts().idxmax()
menos_vendido=tienda['Producto'].value_counts().idxmin()
vendidos=tienda['Producto'].value_counts()
vendidos.plot(kind='bar',figsize=(12,3),color='purple',xlabel='Producto',ylabel='Cantidad',title='Productos mas vendidos')
print(f'el producto mas vendido es {mas_vendido} y el menos vendido {menos_vendido}')
precios_maximos=tienda[['Producto','Precio']].sort_values(by='Precio',ascending=False).head(10)
precios_maximos
# Out:
# el producto mas vendido es Microondas y el menos vendido Auriculares con micrófono
#            Producto     Precio
# 1675  TV LED UHD 4K  2977000.0
# 1020  TV LED UHD 4K  2975000.0
# 1815  TV LED UHD 4K  2966100.0
# 129   TV LED UHD 4K  2910000.0
# 1772  TV LED UHD 4K  2889300.0
# 306   TV LED UHD 4K  2877500.0
# 139   TV LED UHD 4K  2872800.0
# 793   TV LED UHD 4K  2827400.0
# 118   TV LED UHD 4K  2824600.0
# 1778  TV LED UHD 4K  2809600.0

# %%
mas_vendido2=tienda2['Producto'].value_counts().idxmax()
menos_vendido2=tienda2['Producto'].value_counts().idxmin()
vendidos2=tienda2['Producto'].value_counts()
vendidos2.plot(kind='bar',figsize=(12,3),color='green',xlabel='Producto',ylabel='Cantidad',title='Productos mas vendidos')
print(f'el producto mas vendido es {mas_vendido2} y el menos vendido {menos_vendido2}')
precios_maximos2=tienda2[['Producto','Precio']].sort_values(by='Precio',ascending=False).head(10)
precios_maximos
# Out:
# el producto mas vendido es Iniciando en programación y el menos vendido Juego de mesa
#            Producto     Precio
# 1675  TV LED UHD 4K  2977000.0
# 1020  TV LED UHD 4K  2975000.0
# 1815  TV LED UHD 4K  2966100.0
# 129   TV LED UHD 4K  2910000.0
# 1772  TV LED UHD 4K  2889300.0
# 306   TV LED UHD 4K  2877500.0
# 139   TV LED UHD 4K  2872800.0
# 793   TV LED UHD 4K  2827400.0
# 118   TV LED UHD 4K  2824600.0
# 1778  TV LED UHD 4K  2809600.0

# %%
mas_vendido3=tienda3['Producto'].value_counts().idxmax()
menos_vendido3=tienda3['Producto'].value_counts().idxmin()
vendidos3=tienda3['Producto'].value_counts()
vendidos3.plot(kind='bar',figsize=(15,3),color='blue',xlabel='Producto',ylabel='Cantidad',title='Productos mas vendidos')
print(f'el producto mas vendido es {mas_vendido3} y el menos vendido {menos_vendido3}')
precios_maximos3=tienda3[['Producto','Precio']].sort_values(by='Precio',ascending=False).head(10)
precios_maximos3
# Out:
# el producto mas vendido es Kit de bancas y el menos vendido Bloques de construcción
#            Producto     Precio
# 2295  TV LED UHD 4K  2968200.0
# 1344  TV LED UHD 4K  2936200.0
# 360   TV LED UHD 4K  2883700.0
# 58    TV LED UHD 4K  2873900.0
# 1835  TV LED UHD 4K  2852200.0
# 823   TV LED UHD 4K  2799500.0
# 687   TV LED UHD 4K  2764100.0
# 2170  TV LED UHD 4K  2754400.0
# 1703  TV LED UHD 4K  2714100.0
# 1631  TV LED UHD 4K  2613500.0

# %%
mas_vendido4=tienda4['Producto'].value_counts().idxmax()
menos_vendido4=tienda4['Producto'].value_counts().idxmin()
vendidos4=tienda4['Producto'].value_counts()
vendidos4.plot(kind='bar',figsize=(12,3),color='yellow',xlabel='Producto',ylabel='Cantidad',title='Productos mas vendidos')
print(f'el producto mas vendido es {mas_vendido4} y el menos vendido {menos_vendido4}')
precios_maximos4=tienda4[['Producto','Precio']].sort_values(by='Precio',ascending=False).head(10)
precios_maximos4
# Out:
# el producto mas vendido es Cama box y el menos vendido Guitarra eléctrica
#            Producto     Precio
# 647   TV LED UHD 4K  2902200.0
# 104   TV LED UHD 4K  2899800.0
# 375   TV LED UHD 4K  2861000.0
# 1806  TV LED UHD 4K  2851600.0
# 2336  TV LED UHD 4K  2838500.0
# 929   TV LED UHD 4K  2795200.0
# 214   TV LED UHD 4K  2778800.0
# 603   TV LED UHD 4K  2762900.0
# 1972  TV LED UHD 4K  2747000.0
# 926   TV LED UHD 4K  2739400.0

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
en1=round(tienda['Costo de envío'].mean(),2)
en1
# Out:
# np.float64(26018.61)

# %%
en2=round(tienda2['Costo de envío'].mean(),2)
en2
# Out:
# np.float64(25216.24)

# %%
en3=round(tienda3['Costo de envío'].mean(),2)
en3
# Out:
# np.float64(24805.68)

# %%
en4=round(tienda4['Costo de envío'].mean(),2)
en4
# Out:
# np.float64(23459.46)

# %% [markdown]
# #Visualizaciones

# %%
tienda['Fecha de Compra'] = pd.to_datetime(tienda['Fecha de Compra'])
tienda['Mes'] = tienda['Fecha de Compra'].dt.to_period('M')
ventas_mensuales = tienda.groupby('Mes')['Precio'].mean()
ventas_mensuales.plot(kind='line', figsize=(20,4),color='purple',xlabel='Año-Mes', ylabel='Ventas')
# Out:
# /tmp/ipython-input-1341129076.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   tienda['Fecha de Compra'] = pd.to_datetime(tienda['Fecha de Compra'])
# <Axes: xlabel='Año-Mes', ylabel='Ventas'>

# %%
tienda2['Fecha de Compra'] = pd.to_datetime(tienda2['Fecha de Compra'],dayfirst=True)
tienda2['Mes'] = tienda2['Fecha de Compra'].dt.to_period('M')
ventas_mensuales2 = tienda2.groupby('Mes')['Precio'].mean()
ventas_mensuales2.plot(kind='line', figsize=(20,4),color='green',xlabel='Año-Mes', ylabel='Ventas')
# Out:
# <Axes: xlabel='Año-Mes', ylabel='Ventas'>

# %%
tienda3['Fecha de Compra'] = pd.to_datetime(tienda3['Fecha de Compra'])
tienda3['Mes'] = tienda3['Fecha de Compra'].dt.to_period('M')
ventas_mensuales3 = tienda3.groupby('Mes')['Precio'].mean()
ventas_mensuales3.plot(kind='line', figsize=(12,4),color='blue',xlabel='Año-Mes', ylabel='Ventas')
# Out:
# <Axes: xlabel='Año-Mes', ylabel='Ventas'>

# %%
tienda4['Fecha de Compra'] = pd.to_datetime(tienda4['Fecha de Compra'],dayfirst=True)
tienda4['Mes'] = tienda4['Fecha de Compra'].dt.to_period('M')
ventas_mensuales4 = tienda4.groupby('Mes')['Precio'].mean()
ventas_mensuales4.plot(kind='line', figsize=(12,4),color='yellow',xlabel='Año-Mes', ylabel='Ventas')
# Out:
# <Axes: xlabel='Año-Mes', ylabel='Ventas'>

# %% [markdown]
# #Informe de desempeño de tiendas
# Las 4 sucursales fueron evaluadas en los siguientes cinco aspectos:
#
# 1.   Facturacion: se realizó la sumatoria de todas las ventas registradas de cada  tienda, encontrando que la tienda 4 tiene la menor cifra de ventas.
# 2.   Ventas por categoria: se encontró que las 3 categorias mas vendidas en las cuatro tiendas son : Muebles, Electronicos y Juguetes, en estas categorias las tiendas con mas productos vendidos son la 3 y la 4, al llegar a la cuarta categoria mas vendida encontramos que mientras las tiendas de la 1 a la 3 venden mas Electrodomesticos, la tienda 4 vende mas articulos de deporte, los cuales tienen un precio inferior en promedio a los Electrodomesticos.
# 3.   Calificacion promedio de cada tienda: se evaluo las calificaciones del publico hallando que todas las tiendas presentan una calificaión promedio de 4, la tienda uno es la unica con una calificacion un poco inferior de 3.9
# 4.  Productos mas y menos vendidos: pusimos en una grafica los productos para saber cuales son los que se venden mas y menos, para tener una referencia de comparacion hacemos una lista de los productos mas caros en el inventario, encontrando que los productos mas caros son las TV LED UHD 4K.
# La tienda 1 muestra las TV LED UHD 4K como su producto mas vendido, las otras tiendas venden estos productos con una frecuencia media
# 5.   Envio promedio por tienda: Considerando el costo promedio de envio por tienda encontramos que el delivery a la tienda 1 es en promedio el mas caro y el de la tienda 4 el mas barato
# 6.   Promedio de Facturacion mensual: consideramos ademas realizar una grafica de la facturacion por meses para ver la evolucion de ventas de cada tienda, encontramos que en general las tiendas 1 y 2 se mantienen en un rango entre 650000 y 400000, la tienda 3 alcanza un rango entre 650000 y 350000, mientras que la tienda 4 tiene un rango entre 600000 y 300000.
# Tomando en consideración estos puntos evaluados encontramos que la tienda con menor rentabilidad es la tienda 4, si desea vender una sucursal recomiendo vender la tienda 4

# %% [markdown]
# #Analisis de Desempeño Geografico
